# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
from tensorflow.keras.regularizers import l2
import os

# %%
# --- VARIABLES Y COLUMNAS ---
cols_fecha = ['year', 'month', 'day']
cols_elo = ['elo_h', 'elo_a']
cols_avanzadas = [
    'rest_days_home', 'rest_days_away', 
    'avg_pts_scored_home', 'avg_pts_allowed_home', 
    'avg_pts_scored_away', 'avg_pts_allowed_away',
    'avg_efg_home', 'avg_tov_pct_home', 'avg_oreb_pct_home', 'avg_dreb_pct_home', 'avg_ft_rate_home', # 4 Factores Local
    'avg_efg_away', 'avg_tov_pct_away', 'avg_oreb_pct_away', 'avg_dreb_pct_away', 'avg_ft_rate_away'  # 4 Factores Visitante
]
cols_equipos = []

# %%
# --- 1. FUNCIÓN PARA CALCULAR LOS FOUR FACTORS (COMPLETA) ---
def calcular_four_factors(ruta_games):
    print("Calculando los 'Four Factors' completos de Dean Oliver...")
    cols = ['game_date', 'team_id_home', 'team_id_away',
            'fgm_home', 'fga_home', 'fg3m_home', 'tov_home', 'fta_home', 'ftm_home', 'oreb_home', 'dreb_home',
            'fgm_away', 'fga_away', 'fg3m_away', 'tov_away', 'fta_away', 'ftm_away', 'oreb_away', 'dreb_away']
    
    games = pd.read_csv(ruta_games, usecols=cols).dropna()
    games['game_date'] = pd.to_datetime(games['game_date'])

    # 4 Factores del Local
    games['efg_home'] = (games['fgm_home'] + 0.5 * games['fg3m_home']) / games['fga_home']
    games['tov_pct_home'] = games['tov_home'] / (games['fga_home'] + 0.44 * games['fta_home'] + games['tov_home'])
    games['oreb_pct_home'] = games['oreb_home'] / (games['oreb_home'] + games['dreb_away'])
    games['dreb_pct_home'] = games['dreb_home'] / (games['dreb_home'] + games['oreb_away'])
    games['ft_rate_home'] = games['ftm_home'] / games['fga_home']

    # 4 Factores del Visitante
    games['efg_away'] = (games['fgm_away'] + 0.5 * games['fg3m_away']) / games['fga_away']
    games['tov_pct_away'] = games['tov_away'] / (games['fga_away'] + 0.44 * games['fta_away'] + games['tov_away'])
    games['oreb_pct_away'] = games['oreb_away'] / (games['oreb_away'] + games['dreb_home'])
    games['dreb_pct_away'] = games['dreb_away'] / (games['dreb_away'] + games['oreb_home'])
    games['ft_rate_away'] = games['ftm_away'] / games['fga_away']

    # Separar en dos DataFrames para el historial de cada equipo
    home_ff = games[['game_date', 'team_id_home', 'efg_home', 'tov_pct_home', 'oreb_pct_home', 'dreb_pct_home', 'ft_rate_home']].copy()
    home_ff.columns = ['game_date', 'team_id', 'efg', 'tov_pct', 'oreb_pct', 'dreb_pct', 'ft_rate']

    away_ff = games[['game_date', 'team_id_away', 'efg_away', 'tov_pct_away', 'oreb_pct_away', 'dreb_pct_away', 'ft_rate_away']].copy()
    away_ff.columns = ['game_date', 'team_id', 'efg', 'tov_pct', 'oreb_pct', 'dreb_pct', 'ft_rate']

    team_ff = pd.concat([home_ff, away_ff]).sort_values(['team_id', 'game_date']).reset_index(drop=True)

    # Calcular la media móvil de los últimos 5 partidos para cada factor
    team_ff['avg_efg_5'] = team_ff.groupby('team_id')['efg'].transform(lambda x: x.rolling(5).mean().shift(1)).fillna(0.50)
    team_ff['avg_tov_pct_5'] = team_ff.groupby('team_id')['tov_pct'].transform(lambda x: x.rolling(5).mean().shift(1)).fillna(0.15)
    team_ff['avg_oreb_pct_5'] = team_ff.groupby('team_id')['oreb_pct'].transform(lambda x: x.rolling(5).mean().shift(1)).fillna(0.25)
    team_ff['avg_dreb_pct_5'] = team_ff.groupby('team_id')['dreb_pct'].transform(lambda x: x.rolling(5).mean().shift(1)).fillna(0.75)
    team_ff['avg_ft_rate_5'] = team_ff.groupby('team_id')['ft_rate'].transform(lambda x: x.rolling(5).mean().shift(1)).fillna(0.20)

    return team_ff[['game_date', 'team_id', 'avg_efg_5', 'avg_tov_pct_5', 'avg_oreb_pct_5', 'avg_dreb_pct_5', 'avg_ft_rate_5']]

# %%
# --- 2. OHE Y PREPARACIÓN GENERAL ---
def preparar_datos_ohe(df, cols_equipos):
    df_copy = df.copy()
    df_copy['game_date'] = pd.to_datetime(df_copy['game_date'])
    df_copy['year'] = df_copy['game_date'].dt.year
    df_copy['month'] = df_copy['game_date'].dt.month
    df_copy['day'] = df_copy['game_date'].dt.day

    df_copy = pd.get_dummies(df_copy, columns=['team_abbreviation_home','team_abbreviation_away'], dtype=float)
    if not cols_equipos:
        cols_equipos = [c for c in df_copy.columns if 'team_abbreviation_home_' in c or 'team_abbreviation_away_' in c]
    return df_copy, cols_equipos

# %%
# --- 3. FEATURES AVANZADAS (PUNTOS + FOUR FACTORS) ---
def generar_features_avanzadas(df, df_four_factors):
    df_copy = df.copy()
    df_copy['game_date'] = pd.to_datetime(df_copy['game_date'])
    df_copy = df_copy.sort_values('game_date').reset_index(drop=True)

    home_df = df_copy[['game_date', 'team_id_home', 'pts_home', 'pts_away']].rename(
        columns={'team_id_home': 'team_id', 'pts_home': 'pts_scored', 'pts_away': 'pts_allowed'})
    home_df['is_home'] = 1

    away_df = df_copy[['game_date', 'team_id_away', 'pts_away', 'pts_home']].rename(
        columns={'team_id_away': 'team_id', 'pts_away': 'pts_scored', 'pts_home': 'pts_allowed'})
    away_df['is_home'] = 0

    team_games = pd.concat([home_df, away_df]).sort_values(['team_id', 'game_date']).reset_index(drop=True)

    # Cruzar con los 4 factores
    team_games = pd.merge(team_games, df_four_factors, on=['game_date', 'team_id'], how='left')

    # Rellenar nulos de inicio de temporada con valores NBA promedio
    team_games['avg_efg_5'] = team_games['avg_efg_5'].fillna(0.50)
    team_games['avg_tov_pct_5'] = team_games['avg_tov_pct_5'].fillna(0.15)
    team_games['avg_oreb_pct_5'] = team_games['avg_oreb_pct_5'].fillna(0.25)
    team_games['avg_dreb_pct_5'] = team_games['avg_dreb_pct_5'].fillna(0.75) 
    team_games['avg_ft_rate_5'] = team_games['avg_ft_rate_5'].fillna(0.20)
    
    # Días de descanso y Puntos Promedio
    team_games['rest_days'] = team_games.groupby('team_id')['game_date'].diff().dt.days
    team_games['rest_days'] = team_games['rest_days'].fillna(14).clip(upper=14)
    team_games['avg_pts_scored_5'] = team_games.groupby('team_id')['pts_scored'].transform(lambda x: x.rolling(5).mean().shift(1)).fillna(100)
    team_games['avg_pts_allowed_5'] = team_games.groupby('team_id')['pts_allowed'].transform(lambda x: x.rolling(5).mean().shift(1)).fillna(100)
    
    # Separar Locales 
    cols_home = ['game_date', 'team_id', 'rest_days', 'avg_pts_scored_5', 'avg_pts_allowed_5', 'avg_efg_5', 'avg_tov_pct_5', 'avg_oreb_pct_5', 'avg_dreb_pct_5', 'avg_ft_rate_5']
    home_features = team_games[team_games['is_home'] == 1][cols_home]
    home_features.columns = ['game_date', 'team_id_home', 'rest_days_home', 'avg_pts_scored_home', 'avg_pts_allowed_home', 'avg_efg_home', 'avg_tov_pct_home', 'avg_oreb_pct_home', 'avg_dreb_pct_home', 'avg_ft_rate_home']

    # Separar Visitantes 
    cols_away = ['game_date', 'team_id', 'rest_days', 'avg_pts_scored_5', 'avg_pts_allowed_5', 'avg_efg_5', 'avg_tov_pct_5', 'avg_oreb_pct_5', 'avg_dreb_pct_5', 'avg_ft_rate_5']
    away_features = team_games[team_games['is_home'] == 0][cols_away]
    away_features.columns = ['game_date', 'team_id_away', 'rest_days_away', 'avg_pts_scored_away', 'avg_pts_allowed_away', 'avg_efg_away', 'avg_tov_pct_away', 'avg_oreb_pct_away', 'avg_dreb_pct_away', 'avg_ft_rate_away']
    
    # Fusionar con dataset original
    df_copy = pd.merge(df_copy, home_features, on=['game_date', 'team_id_home'], how='left')
    df_copy = pd.merge(df_copy, away_features, on=['game_date', 'team_id_away'], how='left')
    df_copy = df_copy.drop_duplicates(subset=['team_id_home', 'team_id_away', 'game_date'])

    return df_copy

# %%
# --- 4. ESCALADO Y PREPARACIÓN FINAL ---
def escalar_datos(df, df_test, cols_no_escalables, cols_escalables):
    scaler = StandardScaler()
    scaler.fit(df[cols_escalables])
    df_escalado = scaler.transform(df[cols_escalables])
    df_test_escalado = scaler.transform(df_test[cols_escalables])
    data_entrada = np.hstack([np.array(df[cols_no_escalables]), df_escalado])
    data_entrada_test = np.hstack([np.array(df_test[cols_no_escalables]), df_test_escalado])
    return data_entrada, data_entrada_test

def preparar_datos_salida(df):
    return np.column_stack((df['pts_home'].values, df['pts_away'].values))

# %%
# ==============================================================================
# ----------------- EJECUCIÓN DEL PIPELINE DE DATOS ----------------------------
# ==============================================================================
print("Cargando datos principales...")
df_partidos_elo1 = pd.read_csv('csv_red/partidos_elo1.csv')
RUTA_GAME = "../../data/inputs/csv/game.csv" 

df_four_factors = calcular_four_factors(RUTA_GAME)
df_partidos_elo1 = generar_features_avanzadas(df_partidos_elo1, df_four_factors)
df_partidos_elo1, cols_equipos = preparar_datos_ohe(df_partidos_elo1, cols_equipos)

partidos_elo1 = df_partidos_elo1[df_partidos_elo1['season_id'].astype(str).str[-4:].astype(int) <= 2017] 
partidos_elo1_test = df_partidos_elo1[df_partidos_elo1['season_id'].astype(str).str[-4:].astype(int) > 2017] 

todas_cols_escalables = cols_fecha + cols_elo + cols_avanzadas
data_entrada_elo1, data_entrada_elo1_test = escalar_datos(partidos_elo1, partidos_elo1_test, cols_equipos, todas_cols_escalables)
data_salida_elo1, data_salida_elo1_test = preparar_datos_salida(partidos_elo1), preparar_datos_salida(partidos_elo1_test)
# Out:
# Cargando datos principales...
# Calculando los 'Four Factors' completos de Dean Oliver...

# %%
# ==============================================================================
# ----------------- ARQUITECTURA LSTM Y ENTRENAMIENTO --------------------------
# ==============================================================================

# PASO CLAVE: Redimensionar de 2D a 3D para la red LSTM -> (samples, timesteps, features)
print("\nTransformando dimensiones tabulares a secuenciales (3D) para LSTM...")
X_train_lstm = np.reshape(data_entrada_elo1, (data_entrada_elo1.shape[0], 1, data_entrada_elo1.shape[1]))
X_test_lstm = np.reshape(data_entrada_elo1_test, (data_entrada_elo1_test.shape[0], 1, data_entrada_elo1_test.shape[1]))
# Out:
# Transformando dimensiones tabulares a secuenciales (3D) para LSTM...

# %%
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
def crear_modelo_lstm(n_features):
    # Definimos la entrada explícitamente
    inputs = tf.keras.Input(shape=(1, n_features))
    
    # Capa LSTM
    # return_sequences=False devuelve solo el último estado
    x = tf.keras.layers.LSTM(128, activation='tanh')(inputs)
    x = tf.keras.layers.Dropout(0.3)(x)
    
    # Capas Densas
    x = tf.keras.layers.Dense(64, activation='elu', kernel_regularizer=l2(0.005))(x)
    x = tf.keras.layers.Dropout(0.2)(x)
    
    # Salida
    outputs = tf.keras.layers.Dense(2, activation='linear')(x)
    
    modelo = tf.keras.Model(inputs=inputs, outputs=outputs)
    
    modelo.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
        loss=tf.keras.losses.Huber(delta=1.2), 
        metrics=['mean_absolute_error']
    )
    return modelo
def evaluar_precision_lstm(modelo, entrada, salida, nombre_modelo):
    predicciones = modelo.predict(entrada, verbose=0)
    mae_home = mean_absolute_error(salida[:, 0], predicciones[:, 0])
    mae_away = mean_absolute_error(salida[:, 1], predicciones[:, 1])
    mae_total = mean_absolute_error(salida, predicciones)
    
    ganador_pred = (predicciones[:, 0] > predicciones[:, 1]).astype(int)
    ganador_real = (salida[:, 0] > salida[:, 1]).astype(int)
    precision = np.mean(ganador_pred == ganador_real) * 100

    print(f"\n--- Resultados {nombre_modelo} ---")
    print(f"Error Promedio Puntos (MAE Total): {mae_total:.2f}")
    print(f"  -> Error Medio Local: {mae_home:.2f}")
    print(f"  -> Error Medio Visitante: {mae_away:.2f}")
    print(f"Precisión Ganador (deducida): {precision:.2f}%")
    return precision, mae_total

# %%
import numpy as np
import tensorflow as tf

# GUARDAMOS la función original
np_prod_original = np.prod

# REDEFINIMOS la función para que sea tolerante a Tensores simbólicos
def patched_prod(a, *args, **kwargs):
    if tf.is_tensor(a):
        # Si es un tensor, devolvemos un valor simbólico compatible
        return tf.reduce_prod(a)
    try:
        return np_prod_original(a, *args, **kwargs)
    except:
        # Si falla por ser tensor simbólico, devolvemos 1 (o lo que TF necesite para seguir)
        return 1 

np.prod = patched_prod
print("Parche de NumPy aplicado. Intenta crear el modelo ahora.")
# Out:
# Parche de NumPy aplicado. Intenta crear el modelo ahora.

# %%
# Creación e instanciación del modelo LSTM
n_features_totales = data_entrada_elo1.shape[1]
modelo_lstm = crear_modelo_lstm(n_features_totales)

print("\nIniciando entrenamiento del Modelo LSTM (puede tardar más que la red Densa)...")

# Ahora sí, el entrenamiento real con el modelo de la Clase
history_lstm = modelo_lstm.fit(
    X_train_lstm, 
    data_salida_elo1, 
    epochs=1500,           # Empieza con 500, 1500 quizás es mucho para empezar
    batch_size=32, 
    validation_split=0.1, 
    verbose=1,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss', 
            patience=20, 
            restore_best_weights=True
        )
    ]
)

# Evaluación
acc_lstm, mae_lstm = evaluar_precision_lstm(modelo_lstm, X_test_lstm, data_salida_elo1_test, "Experimento LSTM (Secuencia 1-Step)")
# Out:
# Iniciando entrenamiento del Modelo LSTM (puede tardar más que la red Densa)...
# Epoch 1/1500
# 148/148 [==============================] - 1s 6ms/step - loss: 101.2890 - mean_absolute_error: 84.4562 - val_loss: 76.3582 - val_mean_absolute_error: 62.9747
# Epoch 2/1500
# 148/148 [==============================] - 0s 3ms/step - loss: 19.9416 - mean_absolute_error: 15.8029 - val_loss: 13.2810 - val_mean_absolute_error: 10.3248
# Epoch 3/1500
# 148/148 [==============================] - 0s 3ms/step - loss: 15.7858 - mean_absolute_error: 12.4985 - val_loss: 12.4319 - val_mean_absolute_error: 9.7651
# Epoch 4/1500
# 148/148 [==============================] - 0s 3ms/step - loss: 15.2679 - mean_absolute_error: 12.2023 - val_loss: 12.1033 - val_mean_absolute_error: 9.5959
# Epoch 5/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 15.0162 - mean_absolute_error: 12.0843 - val_loss: 12.0113 - val_mean_absolute_error: 9.6247
# Epoch 6/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 14.9113 - mean_absolute_error: 12.0790 - val_loss: 11.9080 - val_mean_absolute_error: 9.6133
# Epoch 7/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 14.6380 - mean_absolute_error: 11.9150 - val_loss: 11.7515 - val_mean_absolute_error: 9.5389
# Epoch 8/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 14.4339 - mean_absolute_error: 11.8041 - val_loss: 11.6242 - val_mean_absolute_error: 9.4780
# Epoch 9/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 14.2449 - mean_absolute_error: 11.6992 - val_loss: 11.5301 - val_mean_absolute_error: 9.4480
# Epoch 10/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 13.9917 - mean_absolute_error: 11.5370 - val_loss: 12.0068 - val_mean_absolute_error: 9.9250
# Epoch 11/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 13.9408 - mean_absolute_error: 11.5429 - val_loss: 11.5332 - val_mean_absolute_error: 9.5631
# Epoch 12/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 13.6882 - mean_absolute_error: 11.3657 - val_loss: 11.3757 - val_mean_absolute_error: 9.4484
# Epoch 13/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 13.7269 - mean_absolute_error: 11.4306 - val_loss: 11.3095 - val_mean_absolute_error: 9.4258
# Epoch 14/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 13.6961 - mean_absolute_error: 11.4416 - val_loss: 11.2264 - val_mean_absolute_error: 9.3960
# Epoch 15/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 13.4858 - mean_absolute_error: 11.2966 - val_loss: 11.1612 - val_mean_absolute_error: 9.3736
# Epoch 16/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 13.2281 - mean_absolute_error: 11.1070 - val_loss: 11.0661 - val_mean_absolute_error: 9.3162
# Epoch 17/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 13.3237 - mean_absolute_error: 11.2122 - val_loss: 10.9781 - val_mean_absolute_error: 9.2612
# Epoch 18/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 13.2443 - mean_absolute_error: 11.1668 - val_loss: 11.1002 - val_mean_absolute_error: 9.3913
# Epoch 19/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 12.9990 - mean_absolute_error: 10.9858 - val_loss: 10.9632 - val_mean_absolute_error: 9.2994
# Epoch 20/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 12.8489 - mean_absolute_error: 10.8788 - val_loss: 11.0615 - val_mean_absolute_error: 9.3844
# Epoch 21/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 12.7829 - mean_absolute_error: 10.8445 - val_loss: 10.9738 - val_mean_absolute_error: 9.3546
# Epoch 22/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 12.7877 - mean_absolute_error: 10.8632 - val_loss: 10.9020 - val_mean_absolute_error: 9.2937
# Epoch 23/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 12.9037 - mean_absolute_error: 10.9800 - val_loss: 10.8554 - val_mean_absolute_error: 9.2796
# Epoch 24/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 12.7593 - mean_absolute_error: 10.8724 - val_loss: 10.7780 - val_mean_absolute_error: 9.2285
# Epoch 25/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 12.6139 - mean_absolute_error: 10.7633 - val_loss: 10.7973 - val_mean_absolute_error: 9.2530
# Epoch 26/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 12.4527 - mean_absolute_error: 10.6466 - val_loss: 10.7637 - val_mean_absolute_error: 9.2430
# Epoch 27/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 12.4410 - mean_absolute_error: 10.6497 - val_loss: 10.7180 - val_mean_absolute_error: 9.2231
# Epoch 28/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 12.5138 - mean_absolute_error: 10.7242 - val_loss: 10.6399 - val_mean_absolute_error: 9.1645
# Epoch 29/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 12.4082 - mean_absolute_error: 10.6439 - val_loss: 10.6914 - val_mean_absolute_error: 9.2156
# Epoch 30/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 12.4746 - mean_absolute_error: 10.7069 - val_loss: 10.6100 - val_mean_absolute_error: 9.1546
# Epoch 31/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 12.4820 - mean_absolute_error: 10.7256 - val_loss: 10.6751 - val_mean_absolute_error: 9.2181
# Epoch 32/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 12.1622 - mean_absolute_error: 10.4681 - val_loss: 10.5721 - val_mean_absolute_error: 9.1488
# Epoch 33/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 12.2257 - mean_absolute_error: 10.5342 - val_loss: 10.5757 - val_mean_absolute_error: 9.1609
# Epoch 34/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.8743 - mean_absolute_error: 10.2476 - val_loss: 10.4847 - val_mean_absolute_error: 9.0997
# Epoch 35/1500
# 148/148 [==============================] - 0s 3ms/step - loss: 12.1014 - mean_absolute_error: 10.4473 - val_loss: 10.5020 - val_mean_absolute_error: 9.1168
# Epoch 36/1500
# 148/148 [==============================] - 0s 3ms/step - loss: 12.1380 - mean_absolute_error: 10.4849 - val_loss: 10.7188 - val_mean_absolute_error: 9.3080
# Epoch 37/1500
# 148/148 [==============================] - 0s 3ms/step - loss: 11.9098 - mean_absolute_error: 10.3057 - val_loss: 10.6244 - val_mean_absolute_error: 9.2426
# Epoch 38/1500
# 148/148 [==============================] - 0s 3ms/step - loss: 11.8121 - mean_absolute_error: 10.2276 - val_loss: 10.5628 - val_mean_absolute_error: 9.1897
# Epoch 39/1500
# 148/148 [==============================] - 0s 3ms/step - loss: 11.8621 - mean_absolute_error: 10.2792 - val_loss: 10.6116 - val_mean_absolute_error: 9.2326
# Epoch 40/1500
# 148/148 [==============================] - 0s 3ms/step - loss: 11.9955 - mean_absolute_error: 10.3933 - val_loss: 10.4423 - val_mean_absolute_error: 9.1078
# Epoch 41/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.9050 - mean_absolute_error: 10.3271 - val_loss: 10.4532 - val_mean_absolute_error: 9.1195
# Epoch 42/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.7459 - mean_absolute_error: 10.1992 - val_loss: 10.4930 - val_mean_absolute_error: 9.1578
# Epoch 43/1500
# 148/148 [==============================] - 0s 3ms/step - loss: 11.7508 - mean_absolute_error: 10.2090 - val_loss: 10.4114 - val_mean_absolute_error: 9.0909
# Epoch 44/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.7375 - mean_absolute_error: 10.2036 - val_loss: 10.4045 - val_mean_absolute_error: 9.0961
# Epoch 45/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.7871 - mean_absolute_error: 10.2497 - val_loss: 10.4616 - val_mean_absolute_error: 9.1499
# Epoch 46/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.6777 - mean_absolute_error: 10.1640 - val_loss: 10.4860 - val_mean_absolute_error: 9.1739
# Epoch 47/1500
# 148/148 [==============================] - 0s 3ms/step - loss: 11.7248 - mean_absolute_error: 10.2065 - val_loss: 10.4326 - val_mean_absolute_error: 9.1257
# Epoch 48/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.6292 - mean_absolute_error: 10.1301 - val_loss: 10.5354 - val_mean_absolute_error: 9.2208
# Epoch 49/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.3516 - mean_absolute_error: 9.9025 - val_loss: 10.4279 - val_mean_absolute_error: 9.1350
# Epoch 50/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.5603 - mean_absolute_error: 10.0830 - val_loss: 10.4980 - val_mean_absolute_error: 9.1966
# Epoch 51/1500
# 148/148 [==============================] - 0s 3ms/step - loss: 11.5518 - mean_absolute_error: 10.0789 - val_loss: 10.5049 - val_mean_absolute_error: 9.2062
# Epoch 52/1500
# 148/148 [==============================] - 1s 4ms/step - loss: 11.4529 - mean_absolute_error: 9.9989 - val_loss: 10.3564 - val_mean_absolute_error: 9.0834
# Epoch 53/1500
# 148/148 [==============================] - 0s 3ms/step - loss: 11.5041 - mean_absolute_error: 10.0462 - val_loss: 10.3845 - val_mean_absolute_error: 9.1167
# Epoch 54/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.3769 - mean_absolute_error: 9.9410 - val_loss: 10.3390 - val_mean_absolute_error: 9.0703
# Epoch 55/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.5011 - mean_absolute_error: 10.0506 - val_loss: 10.3499 - val_mean_absolute_error: 9.0916
# Epoch 56/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.3067 - mean_absolute_error: 9.8913 - val_loss: 10.3848 - val_mean_absolute_error: 9.1197
# Epoch 57/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.2321 - mean_absolute_error: 9.8325 - val_loss: 10.3065 - val_mean_absolute_error: 9.0620
# Epoch 58/1500
# 148/148 [==============================] - 0s 3ms/step - loss: 11.3185 - mean_absolute_error: 9.9052 - val_loss: 10.3590 - val_mean_absolute_error: 9.1020
# Epoch 59/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.2822 - mean_absolute_error: 9.8775 - val_loss: 10.3900 - val_mean_absolute_error: 9.1411
# Epoch 60/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.3588 - mean_absolute_error: 9.9437 - val_loss: 10.3583 - val_mean_absolute_error: 9.1158
# Epoch 61/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.2034 - mean_absolute_error: 9.8151 - val_loss: 10.3895 - val_mean_absolute_error: 9.1309
# Epoch 62/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.3170 - mean_absolute_error: 9.9130 - val_loss: 10.3145 - val_mean_absolute_error: 9.0837
# Epoch 63/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.2815 - mean_absolute_error: 9.8868 - val_loss: 10.2975 - val_mean_absolute_error: 9.0703
# Epoch 64/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.1459 - mean_absolute_error: 9.7736 - val_loss: 10.4275 - val_mean_absolute_error: 9.1749
# Epoch 65/1500
# 148/148 [==============================] - 0s 3ms/step - loss: 11.1175 - mean_absolute_error: 9.7512 - val_loss: 10.3602 - val_mean_absolute_error: 9.1184
# Epoch 66/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.0627 - mean_absolute_error: 9.7073 - val_loss: 10.3893 - val_mean_absolute_error: 9.1491
# Epoch 67/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.2083 - mean_absolute_error: 9.8330 - val_loss: 10.4174 - val_mean_absolute_error: 9.1792
# Epoch 68/1500
# 148/148 [==============================] - 0s 3ms/step - loss: 11.2264 - mean_absolute_error: 9.8506 - val_loss: 10.3003 - val_mean_absolute_error: 9.0761
# Epoch 69/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 10.9777 - mean_absolute_error: 9.6446 - val_loss: 10.4329 - val_mean_absolute_error: 9.1952
# Epoch 70/1500
# 148/148 [==============================] - 0s 3ms/step - loss: 11.1586 - mean_absolute_error: 9.7964 - val_loss: 10.4717 - val_mean_absolute_error: 9.2222
# Epoch 71/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.1713 - mean_absolute_error: 9.8082 - val_loss: 10.4781 - val_mean_absolute_error: 9.2274
# Epoch 72/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.0205 - mean_absolute_error: 9.6840 - val_loss: 10.3475 - val_mean_absolute_error: 9.1213
# Epoch 73/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 10.9254 - mean_absolute_error: 9.6046 - val_loss: 10.6395 - val_mean_absolute_error: 9.3674
# Epoch 74/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 10.8553 - mean_absolute_error: 9.5477 - val_loss: 10.4891 - val_mean_absolute_error: 9.2405
# Epoch 75/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.1066 - mean_absolute_error: 9.7576 - val_loss: 10.4355 - val_mean_absolute_error: 9.1967
# Epoch 76/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.0662 - mean_absolute_error: 9.7282 - val_loss: 10.4899 - val_mean_absolute_error: 9.2467
# Epoch 77/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 10.9372 - mean_absolute_error: 9.6200 - val_loss: 10.5587 - val_mean_absolute_error: 9.3009
# Epoch 78/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 10.8992 - mean_absolute_error: 9.5906 - val_loss: 10.3350 - val_mean_absolute_error: 9.1217
# Epoch 79/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 10.8570 - mean_absolute_error: 9.5566 - val_loss: 10.4013 - val_mean_absolute_error: 9.1716
# Epoch 80/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 10.8935 - mean_absolute_error: 9.5879 - val_loss: 10.4418 - val_mean_absolute_error: 9.2133
# Epoch 81/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 10.9201 - mean_absolute_error: 9.6103 - val_loss: 10.3658 - val_mean_absolute_error: 9.1487
# Epoch 82/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 11.0327 - mean_absolute_error: 9.7045 - val_loss: 10.3073 - val_mean_absolute_error: 9.1017
# Epoch 83/1500
# 148/148 [==============================] - 0s 2ms/step - loss: 10.8745 - mean_absolute_error: 9.5741 - val_loss: 10.4016 - val_mean_absolute_error: 9.1745
#
# --- Resultados Experimento LSTM (Secuencia 1-Step) ---
# Error Promedio Puntos (MAE Total): 9.94
#   -> Error Medio Local: 9.81
#   -> Error Medio Visitante: 10.08
# Precisión Ganador (deducida): 64.86%
